# %% [markdown]
# ## __Lesson 04__

# %% [markdown]
# ## __Demo: Error Handling in Python__
# __Scenario:__
#
# We will create a program that asks the user to enter a file name. The program will try to open the file and read its contents and display them. If the file does not exist, the program will catch the error and inform the user that the file was not found. Regardless of whether the file was found or not, the program will always close the file at the end.

# %%
try:
    a = 5/0
    print(a)
except:
    #optional
    print("error occureddddd")
# Out:
# error occureddd

# %%
try:
    a = 5/0
    print(a)
except Exception as thiru:
    #optional
    print("error occured : ", thiru)
# Out:
# error occured :  division by zero

# %%
try:
    a = 5/0
    print(a)
except Exception as e:
    #optional
    print("error occured : ", e)
# Out:
# error occured :  division by zero

# %%
# Out:
# enter the age dshgkj
# 'dshgkj'

# %%
try:
    age = int(input("enter the age"))
    result = 2000/age
    print(result)
except Exception as e:
    print("some other error occured : ", e)
except ValueError as e:
    print("Value error", e)
except ZeroDivisionError as e:
    print("ZeroDivisionError", e)

finally:
    print("Execution is done")
x = 1+9
print(x)
# Out:
# enter the age 0
# ZeroDivisionError division by zero
# Execution is done
# 10

# %%
x = -2
if x<0:
    raise ValueError("x must be non negative")
def file_demo():
    try:
        # Ask the user for the file name
        file_name = input("Enter the file name: ")

        # Try to open the file and read its content
        file = open(file_name, 'r')
        content = file.read()
        print("File content:")
        print(content)

    except FileNotFoundError:
        # If the file is not found, this block runs
        print("Error: File not found.")

    finally:
        # This block runs regardless of whether an error occurred
        print("Closing file if open.")
        try:
            file.close()
        except:
            print("File was never opened.")

# Call the demo function
file_demo()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_175/4273373503.py in <cell line: 2>()
#       1 x = -2
#       2 if x<0:
# ----> 3     raise ValueError("x must be non negative")
#       4 def file_demo():
#       5     try:
#
# ValueError: x must be non negative

# %%
x = -1
if x<0:
    print("x must be non negative")

# %%
x = -1
if x<0:
print("x must be non negative")
# Out:
#   File "/tmp/ipykernel_224/343513636.py", line 3
#     print("x must be non negative")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
def Function1(): #parameters. arguments
    print("welcome")

# %%
a = Function1()
# Out:
# welcome

# %%
def Function2(): #parameters. arguments
    return str(456)

# %%
b = Function2()

# %%
type(b)
# Out:
# str

# %%
b
# Out:
# '456'

# %%
def suma(a, b):
    res = a+a
    return res

# %%
suma(10,20)
# Out:
# 20

# %%
suma(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_224/2748341361.py in <cell line: 1>()
# ----> 1 suma(10)
#
# TypeError: suma() missing 1 required positional argument: 'b'

# %%
suma(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_251/1213446296.py in <cell line: 1>()
# ----> 1 suma(1,2,3)
#
# TypeError: suma() takes 2 positional arguments but 3 were given

# %%
print()

# %%
def suma(a=10,c, b):
    res = a+b
    return res
# Out:
#   File "/tmp/ipykernel_251/2654428547.py", line 1
#     def suma(a=10,c, b):
#                   ^
# SyntaxError: non-default argument follows default argument

# %%
suma()
# Out:
# 210

# %% [markdown]
# # Variable length arguments

# %%
def collect(*numbers):
    total =0
    count=0
    for i in numbers:
        total += i
        count += 1
    return total, count

# %%
collect(5,10,15,20,30,1,2,3,5,6)
# Out:
# (97, 10)

# %% [markdown]
# # Keyword based variable length arguments

# %%
def collect2(**numbers):
    try:
        total_custmer_age =0
        count=0
        for key, value in numbers.items():
            total_custmer_age += value
            count += 1
    except:
        print("error")
    return total_custmer_age, count

# %%
def sum1(**b):
    t=0
    for i in b.values():
        t+=i
    return t

# %%
sum1(a=10, v=0)
# Out:
# 10

# %%
collect2(a=10, b=5)
# Out:
# (15, 2)

# %%
def collectdict(numbers):
    try:
        total =0
        count=0
        for key, value in numbers.items():
            total += value
            count += 1
    except:
        print("error")
    return total, count

dict1 = {"A":10, "B":20, "c":30}
collectdict(dict1)
# Out:
# (60, 3)

# %%
dict1 = {"A":10, "B":20, "c":30, "A":40}
dict1
# Out:
# {'A': 40, 'B': 20, 'c': 30}

# %%
def file_demo():
    try:
        # Ask the user for the file name
        file_name = input("Enter the file name: ")

        # Try to open the file and read its content
        file = open(file_name, 'r')
        content = file.read()
        print("File content:")
        print(content)

    except FileNotFoundError:
        # If the file is not found, this block runs
        print("Error: File not found.")

    finally:
        # This block runs regardless of whether an error occurred
        print("Closing file if open.")
        try:
            file.close()
        except:
            print("File was never opened.")

# Call the demo function
file_demo()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_251/2144899893.py in <cell line: 1>()
# ----> 1 a
#       2 def file_demo():
#       3     try:
#       4         # Ask the user for the file name
#       5         file_name = input("Enter the file name: ")
#
# NameError: name 'a' is not defined

# %% [markdown]
# - __try__ block: Attempts to open the file and read it
# - __except FileNotFoundError:__ Catches the error when the file doesn't exist and handles it gracefully
# - __finally__ block: Ensures that the file is closed if it was opened or informs the user if the file was never opened

# %%
def file_demo():
    try:
        # Ask the user for the file name
        file_name = input("Enter the file name: ")

        # Try to open the file and read its content
        file = open(file_name, 'r')
        content = file.read()
        print("File content:")
        print(content)

    except FileNotFoundError:
        # If the file is not found, this block runs
        print("Error: File not found.")

    finally:
        # This block runs regardless of whether an error occurred
        print("Closing file if open.")
        try:
            file.close()
        except:
            print("File was never opened.")

# Call the demo function
file_demo()

# %% [markdown]
# ### __How to Use the Demo:__
# __Run the code__
#
# __Case 1:__ When the user inputs an existing file name (For example, example.txt):
#
# - The program will read and display the file's content.
# - The program will close the file successfully and print the message "Closing file if open."
#
# __Case 2:__ When the user inputs a non-existent file name (For example, nonexistent.txt):
#
# - The program will catch the __FileNotFoundError__ and display "Error: File not found."
# - The program will attempt to close the file, but since the file was never opened, the __finally__ block will handle that by printing "File was never opened."
